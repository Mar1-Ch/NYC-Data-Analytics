# %%
import pyarrow.parquet as pq
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pyarrow.parquet as pq
#
# ModuleNotFoundError: No module named 'pyarrow'

# %%
# !pip install pyarrow
# Out:
# ...
#      -------------------------------------- 24.6/24.6 MB 385.8 kB/s eta 0:00:00
# ...

# %%
import pyarrow.parquet as pq

# %%
trips = pq.read_table(r'C:\Users\mchou\Downloads\yellow_tripdata_2023-08.parquet')
trips = trips.to_pandas()

# %%
# !pip install --upgrade pandas pyarrow
# Out:
# ...
#      -------------------------------------- 10.7/10.7 MB 277.4 kB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Zugriff verweigert: 'C:\\Users\\mchou\\AppData\\Local\\Temp\\pip-uninstall-ei59r7n7\\_libs\\algos.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
python -m venv new_env
source new_env/bin/activate  # On Windows, use new_env\Scripts\activate
pip install numexpr pandas pyarrow
# Out:
#   Cell In[10], line 1
#     python -m venv new_env
#               ^
# SyntaxError: invalid syntax

# %%
# !pip install numexpr pandas pyarrow

# %%
conda update pandas pyarrow
# Out:
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: C:\Users\mchou\anaconda3
#   package name: pandas

# %%
trips
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-08-01 00:26:44   2023-08-01 00:45:25              1.0
# 1               1  2023-08-01 00:55:42   2023-08-01 01:00:53              1.0
# 2               2  2023-08-01 00:32:04   2023-08-01 01:09:03              1.0
# 3               2  2023-08-01 00:13:37   2023-08-01 00:41:15              1.0
# 4               1  2023-08-01 00:24:46   2023-08-01 00:41:31              2.0
# ...           ...                  ...                   ...              ...
# 2824204         2  2023-08-31 23:40:14   2023-08-31 23:56:46              NaN
# 2824205         2  2023-08-31 23:15:42   2023-08-31 23:36:57              NaN
# 2824206         2  2023-08-31 23:28:52   2023-08-31 23:52:00              NaN
# 2824207         2  2023-08-31 23:59:58   2023-09-01 00:13:01              NaN
# 2824208         1  2023-08-31 23:32:45   2023-09-01 00:04:36              NaN
#
# ...

# %%
trips.to_csv('dataTrips.csv')
